# %%
import os
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\Venkata Bharadwaj\\OneDrive\\Desktop\\Face_recog'

# %% [markdown]
# ### Changeing Image_urls path

# %%
def Image_url(file_name,file_path):
    
    new = []
    
    #Reading Excel file
    df = pd.read_excel(file_name)
    
    #Reading Csv file
    #df = pd.read_csv(file_name)

    for urls in df["Image_Url"]:
        image_name = urls.split("\\")[-1]
        new.append(os.path.join(file_path,image_name))

    #Replaceing values in the Image_url into new Urls
    df["Image_Url"] = new
    
    return df

# %%
news = Image_url('office project3.xlsx',r'C:\\Users\\Venkata Bharadwaj\\OneDrive\\Desktop\\Face_recog')
news.to_csv("C:\\Users\\Venkata Bharadwaj\\OneDrive\\Desktop\\Face_recog\\ne")

# %%
df = pd.read_excel("office project3.xlsx")

# %%
# Out:
#                                              Tag_Name  Color   Shape  \
# 0                                      1-500x500.jpeg    red  vector
# 1   14-blank-price-tag-png-free-cliparts-that-you-...    red  vector
# 2   183-1837940_retro-price-tag-png-download-price...   grey   mixed
# 3          19-194837_labels-vector-price-tag-sign.png  mixed  square
# 4                             220px-Pricetag_roll.png    red  Circle
# ..                                                ...    ...     ...
# 93                                       images23.jpg  mixed   mixed
# 94                                       images24.jpg  mixed   mixed
# 95                                       images25.jpg    red  vector
# 96                                       images26.jpg  mixed   mixed
# 97                                       images27.jpg  mixed  vector
#
#    Bar_Code_Position Price_Position Tag_Size Logo_Position  \
# 0               none           None     none          none
# ...
